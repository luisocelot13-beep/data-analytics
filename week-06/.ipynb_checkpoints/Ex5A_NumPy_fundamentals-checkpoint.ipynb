# %% [markdown]
# # Ex 5.A NumPy Fundamentals

# %%
import numpy as np

# %% [markdown]
# ## Array basics

# %%
fruits =['apple','bannana','cherry','date']

# %%
print(fruits)
# Out:
# ['apple', 'bannana', 'cherry', 'date']

# %%
arr_1 =np.array(fruits)

# %%
print(arr_1)
# Out:
# ['apple' 'bannana' 'cherry' 'date']

# %%
print(arr_1.dtype)
# Out:
# <U7

# %%
print(arr_2)
# Out:
# ((10, 11, 12), (13, 14, 15))

# %%
arr_2 =np.array([(10,11,12),(13,14,15)])

# %%
print(arr_2)
# Out:
# [[10 11 12]
#  [13 14 15]]

# %%
(arr_2.T)
# Out:
# array([[10, 13],
#        [11, 14],
#        [12, 15]])

# %%
# It seems like it break up each tuple vertically.
# it only does it temporarily

# %%
print(arr_2)
# Out:
# [[10 11 12]
#  [13 14 15]]

# %%
arr_3 = np.array([(1,3,5),(2,4,6)])

# %%
print(arr_3)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
arr_4 =np.array([arr_3[0,2],arr_3[1,1]])

# %%
print(arr_4)
# Out:
# [5 4]

# %%
arr_5 =np.ones((2,2,2))

# %%
print(arr_5)
# Out:
# [[[1. 1.]
#   [1. 1.]]
#
#  [[1. 1.]
#   [1. 1.]]]
