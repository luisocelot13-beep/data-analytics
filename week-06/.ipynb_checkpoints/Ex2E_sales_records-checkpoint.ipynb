# %% [markdown]
# # Sales Records Analysis
# ### Author: Luis Ocelotl
# ### Exercise 2.E Using functions for analyzing data

# %% [markdown]
# This notebook analyzes a small sales dataset using Python functions.
# Each function takes the full dataset as its first argument.

# %%
sales_data = [
('Laptop', 'East', 1200.00),
('Phone', 'West', 850.00),
('Tablet', 'East', 400.00),
('Monitor', 'South', 650.00),
('Keyboard', 'West', 75.00),
('Laptop', 'South', 1150.00),
('Phone', 'East', 900.00),
('Tablet', 'West', 425.00),
('Monitor', 'East', 680.00),
('Keyboard', 'South', 80.00),
('Laptop', 'West', 1300.00),
('Phone', 'West', 820.00),
]

# %% [markdown]
# # Lab 1. Total sales by region

# %%
def region_total(data,region):
        return sum( 
            row[2]
            for row in sales_data
                if row[1] == region)

# %%
print(region_total(sales_data,'East'))
# Out:
# 3180.0

# %%
print(region_total(sales_data,'West'))
# Out:
# 3470.0

# %%
print(region_total(sales_data,'South'))
# Out:
# 1880.0

# %% [markdown]
# # Lab 2. Count of sales by region

# %%
def region_count(data,region):
    return sum(
        1
        for row in sales_data
            if row[1] == region)

# %%
print(region_count(sales_data,'East'))
# Out:
# 4

# %%
print(region_count(sales_data,'South'))
# Out:
# 3

# %%
print(region_count(sales_data,'West'))
# Out:
# 5

# %%
# Lab 3 Average sale amount by region

# %%
def region_average(data,region):
    total = region_total(data,region)
    count = region_count(data,region)
    if count == 0:
        return 0
    return total / count

# %%
print(region_average(sales_data,'West'))
# Out:
# 694.0

# %%
print(region_average(sales_data,'East'))
# Out:
# 795.0

# %%
print(region_average(sales_data,'South'))
# Out:
# 626.6666666666666

# %%
print(region_average(sales_data,'North'))
# Out:
# 0

# %% [markdown]
# # Lab 4. Filter by sale amount

# %%
threshold = 500

# %%
def sales_above(data,threshold):
    return [
        row
        for row in data 
        if row[2] > threshold]
results = sales_above(sales_data,threshold)
for product,region,sales in results:
    print(f'Product:{product} |'
          f'Region:{region} |'
          f'Sales: {sales:,.2f}')
# Out:
# Product:Laptop |Region:East |Sales: 1,200.00
# Product:Phone |Region:West |Sales: 850.00
# Product:Monitor |Region:South |Sales: 650.00
# Product:Laptop |Region:South |Sales: 1,150.00
# Product:Phone |Region:East |Sales: 900.00
# Product:Monitor |Region:East |Sales: 680.00
# Product:Laptop |Region:West |Sales: 1,300.00
# Product:Phone |Region:West |Sales: 820.00

# %% [markdown]
# # Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(
        data,
        key=lambda row: row[2])

# %%
print(top_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)

# %%
def bottom_sales(data):
    return min(data,
               key=lambda row: row[2])

# %%
print(bottom_sales(sales_data))
# Out:
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# ## The top sale was laptop in the west region for 1300.00
# ## The bottom sale was keyboard in the west region for 75.00

# %% [markdown]
# # Lab 6. Apply a discount

# %%
def apply_discounts(data,discount_pct):
    return list(map(lambda s:(s[0],s[1],s[2] * (1 - discount_pct)),data))

# %%
print(apply_discounts(sales_data,0.10))
# Out:
# [('Laptop', 'East', 1080.0), ('Phone', 'West', 765.0), ('Tablet', 'East', 360.0), ('Monitor', 'South', 585.0), ('Keyboard', 'West', 67.5), ('Laptop', 'South', 1035.0), ('Phone', 'East', 810.0), ('Tablet', 'West', 382.5), ('Monitor', 'East', 612.0), ('Keyboard', 'South', 72.0), ('Laptop', 'West', 1170.0), ('Phone', 'West', 738.0)]

# %%
print(apply_discounts(sales_data,0.15))
# Out:
# [('Laptop', 'East', 1020.0), ('Phone', 'West', 722.5), ('Tablet', 'East', 340.0), ('Monitor', 'South', 552.5), ('Keyboard', 'West', 63.75), ('Laptop', 'South', 977.5), ('Phone', 'East', 765.0), ('Tablet', 'West', 361.25), ('Monitor', 'East', 578.0), ('Keyboard', 'South', 68.0), ('Laptop', 'West', 1105.0), ('Phone', 'West', 697.0)]

# %% [markdown]
# # Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(row[1] for row in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# # These functions would be used for identify the unique products,customers then getting there total etc.see what item is not in list at all

# %% [markdown]
# # Lab 8. Region summary

# %%
def region_summary(data,region):
    regional_data =[row for row in data
                        if row[1] == region]
    count = region_count(data,region)
    total = region_total(data,region)
    average = region_average(data,region)
    top = top_sale(regional_data)

    print(f'\n==={region} Region ===')
    print(f'Records:     {count}')
    print(f'Total sales: {total:,.2f}')
    print(f'Average Sale: ${average:,.2f}')
    print(f'Top Sale:    {top[0]} - ${top[2]:,.2f}')

# %%
print(region_summary(sales_data,'West'))
# Out:
# ===West Region ===
# Records:     5
# Total sales: 3,470.00
# Average Sale: $694.00
# Top Sale:    Laptop - $1,300.00
# None

# %% [markdown]
# # Lab 9. Full Summary

# %%
for r in unique_regions(sales_data):
    region_summary(sales_data,r)
# Out:
# ===East Region ===
# Records:     4
# Total sales: 3,180.00
# Average Sale: $795.00
# Top Sale:    Laptop - $1,200.00
#
# ===South Region ===
# Records:     3
# Total sales: 1,880.00
# Average Sale: $626.67
# Top Sale:    Laptop - $1,150.00
#
# ===West Region ===
# Records:     5
# Total sales: 3,470.00
# Average Sale: $694.00
# Top Sale:    Laptop - $1,300.00

# %%
# Summary for Ex2E
# With all these labs I learned working with loops including key,lambda,map,set,sorted etc all of these functions are benefitial
# for every day use to get specific data.
